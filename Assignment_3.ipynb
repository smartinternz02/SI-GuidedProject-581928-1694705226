# %% [markdown]
# #Task-1:Download the dataset
# #Task-2: Load the dataset into the tool

# %%
import pandas as pd
data=pd.read_csv('/content/penguins_size.csv')
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
data.shape
# Out:
# (344, 7)

# %% [markdown]
# #3. Perform Below Visualizations.
# ● Univariate Analysis
# ● Bi- Variate Analysis
# ● Multi-Variate Analysis

# %%
#univariate Analysis
import seaborn as sns
sns.distplot(data.culmen_length_mm)
# Out:
# <ipython-input-204-cb39a67ee4a7>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.displot(data.island)

# %%
data.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
data.sex=data.sex.replace('.','MALE')

# %%
data.sex.value_counts()
# Out:
# MALE      169
# FEMALE    165
# Name: sex, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(data.sex.value_counts(),[0,0.1],labels=['MALE','FEMALE'],autopct='%1.1f%%',shadow=True,colors=['r','b'])
plt.title('sex')
plt.show()

# %%
data.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
plt.pie(data.species.value_counts(),[0,0.1,0.1],labels=['Adelie','Gentoo','Chinstrap'],autopct='%1.1f%%',shadow=True,colors=['y','b','g'])
plt.title('species')
plt.show()

# %%
sns.barplot(x=data.body_mass_g.value_counts().index,y=data.body_mass_g.value_counts())
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.barplot(x=data.flipper_length_mm.value_counts().index,y=data.flipper_length_mm.value_counts())
# Out:
# <Axes: ylabel='flipper_length_mm'>

# %%
#bivariate
sns.lineplot(x=data.culmen_length_mm,y=data.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.scatterplot(x=data.culmen_length_mm,y=data.culmen_depth_mm)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
#multivariate
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-217-6c71ac866e2e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# #Task-4:Perform descriptive statistics on the dataset.

# %%
data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# #Task-5:Check for Missing values and deal with them.

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
data.culmen_length_mm=data.culmen_length_mm.fillna(data.culmen_length_mm.median())
data.culmen_depth_mm=data.culmen_depth_mm.fillna(data.culmen_depth_mm.median())
data.flipper_length_mm=data.flipper_length_mm.fillna(data.flipper_length_mm.median())
data.body_mass_g=data.body_mass_g.fillna(data.body_mass_g.median())

# %%
data.sex.mode()
# Out:
# 0    MALE
# Name: sex, dtype: object

# %%
data.sex=data.sex.fillna("MALE")
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
data.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# #Task-6: Find the outliers and replace them outliers

# %%
#outlier detection(by using box graph)
sns.boxplot(data.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(data.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(data.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(data.body_mass_g)
# Out:
# <Axes: >

# %%
#no outliers

# %% [markdown]
# #Task-7: Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data.species=le.fit_transform(data.species)
data.island=le.fit_transform(data.island)
data.sex=le.fit_transform(data.sex)
data.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    1
# 1       3800.0    0
# 2       3250.0    0
# 3       4050.0    1
# 4       3450.0    0

# %% [markdown]
# #Task-8: Check the correlation of independent variables with the target

# %%
data.corr().species.sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# sex                  0.010240
# island              -0.635659
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %% [markdown]
# #Task-9: Split the data into dependent and independent variables.

# %%
#independent variable
x=data.drop(columns=['species'],axis=1)
x.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0

# %%
#dependent variable
y=data.species
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %% [markdown]
# #Task-10: Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

x_scaled= pd.DataFrame(scale.fit_transform(x),columns =x.columns)
x_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.0
# 2  0.0
# 3  1.0
# 4  0.0

# %% [markdown]
# #Task-11: Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=0)

# %%
x_train.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 219     0.5          0.658182         0.666667           0.440678
# 271     0.0          0.596364         0.119048           0.813559
# 266     0.0          0.487273         0.095238           0.644068
# 335     0.0          0.836364         0.345238           0.983051
# 217     0.5          0.636364         0.607143           0.355932
#
#      body_mass_g  sex
# 219     0.298611  0.0
# 271     0.722222  1.0
# 266     0.416667  0.0
# 335     0.875000  1.0
# 217     0.298611  1.0

# %%
x_test.head()
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 141     0.5          0.309091         0.488095           0.254237
# 6       1.0          0.247273         0.559524           0.152542
# 60      0.0          0.130909         0.452381           0.220339
# 249     0.0          0.650909         0.261905           0.813559
# 54      0.0          0.087273         0.595238           0.254237
#
#      body_mass_g  sex
# 141     0.215278  1.0
# 6       0.256944  0.0
# 60      0.125000  0.0
# 249     0.791667  1.0
# 54      0.055556  0.0

# %% [markdown]
# #Task-12: Check the training and testing data shape

# %%
x_train.shape
# Out:
# (240, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
x_test.shape
# Out:
# (104, 6)

# %%
y_test.shape
# Out:
# (104,)
